# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\chand\Downloads\Sample_-_Superstore.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df.drop('Row ID',axis = 1,inplace=True)

# %%
df.drop(['Customer ID','Postal Code'],axis = 1 ,inplace=True)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode    Customer Name  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class      Claire Gute
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class      Claire Gute
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class  Darrin Van Huff
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell
#
#      Segment        Country             City       State Region  \
# 0   Consumer  United States        Henderson    Kentucky  South
# 1   Consumer  United States        Henderson    Kentucky  South
# 2  Corporate  United States      Los Angeles  California   West
# 3   Consumer  United States  Fort Lauderdale     Florida  South
# 4   Consumer  United States  Fort Lauderdale     Florida  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# # Data Cleaning
# Structural Errors , Duplicates, Missing values , Outilers , Type Casting

# %%
df[df.duplicated()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode   Customer Name  \
# 3406  US-2014-150119 2014-04-23 2014-04-27  Standard Class  Laurel Beltran
#
#           Segment        Country      City State Region       Product ID  \
# 3406  Home Office  United States  Columbus  Ohio   East  FUR-CH-10002965
#
#        Category Sub-Category  \
# 3406  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer Name, Segment, Country, City, State, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %%
#missing values
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # typecasting

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df['Sales'].astype('float32')
# Out:
# 0       261.959991
# 1       731.940002
# 2        14.620000
# 3       957.577515
# 4        22.368000
#            ...
# 9989     25.247999
# 9990     91.959999
# 9991    258.575989
# 9992     29.600000
# 9993    243.160004
# Name: Sales, Length: 9993, dtype: float32

# %%
df['Quantity'].astype('int16')
# Out:
# 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9989    3
# 9990    2
# 9991    2
# 9992    4
# 9993    2
# Name: Quantity, Length: 9993, dtype: int16

# %% [markdown]
# # outliers

# %%
df.plot(kind = 'box',figsize = (10,6),subplots = True,layout = (3,2))
plt.show()

# %% [markdown]
# # Univariate Analysis:

# %% [markdown]
# # numerical datatype

# %%
df["Quantity"].plot(kind = "hist",figsize = (6,4),title = "Histogram Of Quantity",color = "red")
plt.show()

# %%
df['Sales'].plot(kind = 'hist',figsize = (6,4),title = 'Sales')
# Out:
# <Axes: title={'center': 'Sales'}, ylabel='Frequency'>

# %%
df['Profit'].plot(kind = 'hist',figsize = (6,4),title = 'Profit')
# Out:
# <Axes: title={'center': 'Profit'}, ylabel='Frequency'>

# %%
df['Discount'].plot(kind = 'hist',figsize = (6,4),title = 'Discount')
# Out:
# <Axes: title={'center': 'Discount'}, ylabel='Frequency'>

# %%
df["Quantity"].plot(kind = 'kde',figsize = (6,4),title = "density Of Quantity")

plt.show()

# %%
df["Sales"].plot(kind = 'kde',figsize = (6,4),title = " density of Sales")

plt.show()

# %%
df["Profit"].plot(kind = 'kde',figsize = (6,4),title = "profit")

plt.show()

# %%
df["Discount"].plot(kind = 'kde',figsize = (6,4),title = "density Of discount")

plt.show()

# %% [markdown]
# # Categorical : countplot,bar plot,pie chart

# %%
sns.countplot(data = df,x = "Ship Mode",color = 'yellow')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
sns.countplot(data = df,x = "Product Name")
# Out:
# <Axes: xlabel='Product Name', ylabel='count'>

# %%
df['Category'].value_counts().plot(kind = 'barh',xlabel = 'Category',figsize = (6,4),color = ['purple','orange','lavender'],title = 'barplot of category')
# Out:
# <Axes: title={'center': 'barplot of category'}, xlabel='Category', ylabel='Category'>

# %%
df["State"].value_counts().plot(kind = "bar",xlabel = "State",figsize = (10,7),color = ["pink","brown","green"],title ='barplot of state')
# Out:
# <Axes: title={'center': 'barplot of state'}, xlabel='State'>

# %%
(df["Region"].value_counts()/len(df["Region"])*100).plot(kind = "pie",autopct = '%1.1f',legend = True)
# Out:
# <Axes: ylabel='count'>

# %%
plt.style.use('dark_background')

# %%
(df["Sub-Category"].value_counts()/len(df["Sub-Category"])*100).plot(kind = "pie",autopct = '%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Bivariate Analysis
# Categorical & Categorical,
# Categorical & Numerical,
# Numerical & Numerical

# %%
pd.crosstab(df['Order ID'],df['Customer Name'])
# Out:
# Customer Name   Aaron Bergman  Aaron Hawkins  Aaron Smayling  Adam Bellavance  \
# Order ID
# CA-2014-100006              0              0               0                0
# CA-2014-100090              0              0               0                0
# CA-2014-100293              0              0               0                0
# CA-2014-100328              0              0               0                0
# CA-2014-100363              0              0               0                0
# ...                       ...            ...             ...              ...
# US-2017-168802              0              0               0                0
# US-2017-169320              0              0               0                0
# US-2017-169488              0              0               0                0
# US-2017-169502              0              0               0                0
# US-2017-169551              0              0               0                0
#
# ...

# %%
sns.countplot(data = df,x = "Ship Mode", hue = "Region")              #categorical vs categorical
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
df['Order Date'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
df.groupby(by = 'Quantity')[['Region','Category']].count()
# Out:
#           Region  Category
# Quantity
# 1            899       899
# 2           2401      2401
# 3           2409      2409
# 4           1191      1191
# 5           1230      1230
# 6            572       572
# 7            606       606
# 8            257       257
# 9            258       258
# 10            57        57
# 11            34        34
# 12            23        23
# 13            27        27
# 14            29        29

# %%
# multivariate

# %%
df.corr(numeric_only = True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200808 -0.028197  0.479067
# Quantity  0.200808  1.000000  0.008680  0.066241
# Discount -0.028197  0.008680  1.000000 -0.219481
# Profit    0.479067  0.066241 -0.219481  1.000000

# %%
df.plot("Profit","Discount",kind = "scatter",figsize = (6,5))
# Out:
# <Axes: xlabel='Profit', ylabel='Discount'>

# %%
df.plot("Profit","Sales",kind = "scatter",figsize = (6,5))
# Out:
# <Axes: xlabel='Profit', ylabel='Sales'>

# %%
sns.heatmap(df.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
