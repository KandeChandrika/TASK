# %% [markdown]
# # Analysis 2
# #1) Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization¶

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats as st
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\chand\Data science\df_stats_cleaned.csv")

# %% [markdown]
# # 1) Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization

# %%
df["brand"].value_counts()
# Out:
# brand
# volkswagen       58984
# bmw              33345
# mercedes_benz    29763
# opel             27600
# audi             27052
# ford             18133
# renault          12178
# peugeot           8344
# fiat              6609
# seat              5251
# skoda             4907
# mazda             4315
# toyota            4004
# citroen           3956
# nissan            3765
# smart             3718
# mini              3040
# hyundai           2972
# volvo             2724
# mitsubishi        2149
# honda             2080
# kia               2070
# porsche           1954
# alfa_romeo        1776
# suzuki            1762
# chevrolet         1509
# chrysler          1095
# dacia              785
# land_rover         694
# jeep               687
# subaru             562
# jaguar             540
# daihatsu           507
# saab               435
# daewoo             331
# lancia             320
# rover              275
# trabant            216
# lada               161
# ...

# %%
df["brand"].value_counts().plot(kind = "bar",xlabel = "brand of a vehicle",ylabel = "no. of vehicles",color = "red")
# Out:
# <Axes: xlabel='brand of a vehicle', ylabel='no. of vehicles'>

# %%
#from the data,volkswagen has the most no of vehicles.
#trabant,lada are the least no of vehicle type.

# %% [markdown]
# # 2)What is the Average price for vehicles based on the type of vehicle as well as on the type of gearbox.Explain me with both numerical and visualization analysis¶

# %%
df.groupby(["vehicleType","gearbox"])["price"].mean()
# Out:
# vehicleType  gearbox
# andere       automatik     8963.811060
#              manuell       4291.629873
# bus          automatik    11111.818360
#              manuell       6631.629608
# cabrio       automatik    16148.505927
#              manuell       8977.921948
# coupe        automatik    19012.865081
#              manuell      12444.911872
# kleinwagen   automatik     4276.086465
#              manuell       3161.149184
# kombi        automatik     9299.356506
#              manuell       5471.045379
# limousine    automatik    11615.488196
#              manuell       6161.581853
# suv          automatik    17278.553939
#              manuell      10456.736365
# Name: price, dtype: float64

# %%
df.groupby(["vehicleType","gearbox"])["price"].mean().plot(kind = "bar",color = ["green","orange"])
# Out:
# <Axes: xlabel='vehicleType,gearbox'>

# %%
# 3) What is the marginal probability of private seller

# %%
(df["seller"].value_counts()/len(df))['privat']               # the marginal prob distn of a private seller
# Out:
# 0.999992871603319
